# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,4,9,16,25]

#Creating a line plot
plt.plot(x,y)
plt.xlabel('X asix')
plt.ylabel('Y label')
plt.title('Basic line plot')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]

plt.plot(x,y,color='green',linestyle=':',marker='o',linewidth=3,markersize=10)
plt.grid(True)

# %%
#Multiple Plot
#Sample Data

x=[1,2,3,4,5]
y1=[1,4,9,16,25]
y2=[1,2,3,4,5]

plt.figure(figsize=(9,5))

plt.subplot(2,2,1)
plt.plot(x,y1,color='green',marker='*',markersize=9)
plt.title('Plot 1')
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(y1,x,color='blue',marker='o',markersize=9)
plt.title('Plot 2')

plt.subplot(2,2,3)
plt.plot(x,y1,color='yellow',marker='*',markersize=9)
plt.title('Plot 3')

# z=x**2

plt.subplot(2,2,4)
plt.plot(y2,x,color='green',marker='*',markersize=9)
plt.title('Plot 4')

# %%
#Bar Plot

categories=['A','B','C','D','E']
values=[5,6,17,8,12]

plt.bar(categories,values,color='purple')

# %%
#Histograms

data=[1,2,3,4,5,6,7,8,2,2,5,4,4,5,6]

plt.hist(data,bins=20,color='orange',edgecolor='black')

# %%
x=[1,2,3,4,5]
y=[2,3,4,5,6]

plt.scatter(x,y,color='red',marker='*')

# %%
#Pie chart

labels=['A','B','C','D']
sizes=[30,40,50,20]
colors=['green','gold','orange','red']
explode=(0.2,0,0,0)

plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct="%1.1f%%",shadow=True)

# %%
#Sales data Visualisation

import pandas as pd

sales_data_df = pd.read_csv('sales_data_sample.csv', encoding='latin1')
sales_data_df.head(5)

# %%
sales_data_df.info()

# %%
#Plotting total sales by price each

total_sales_by_product=sales_data_df.groupby('PRICEEACH')['SALES'].sum()
print(total_sales_by_product)

# %%
total_sales_by_product.plot(kind='bar',color='teal')

# %%
sales_trend=sales_data_df.groupby('SALES')['QUANTITYORDERED'].sum().reset_index()
sales_trend

plt.plot(sales_trend['QUANTITYORDERED'],sales_trend['SALES'])

# %%
import seaborn as sns

#Basic plotting

tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Creating a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('Scatter plot of total bills')
plt.show()

# %%
##Line plot

sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('Line plot of total size/total bill')
plt.show()

# %%
#Categorical Plots

sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bar plot of total bill/day')
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()

sns.violinplot(x='day',y='tip',data=tips)
plt.show()

# %%
#HIstograms

sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#KDE plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.pairplot(tips)

# %%
#Heatmap
correlation=tips[['total_bill','tip','size']].corr()
correlation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
import seaborn as sns
correlation = tips.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import seaborn as sns
# ----> 2 correlation = tips.corr()
#       3 sns.heatmap(corr,annot=True,cmap='coolwarm')
#
# NameError: name 'tips' is not defined

# %%
import pandas as pd 
sales_df=pd.read_csv('data.csv')
sales_df.head(10)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7       450  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Date',y='Calories',data=sales_df,estimator=sum)
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.figure(figsize=(10,7))
#       2 sns.barplot(x='Date',y='Calories',data=sales_df,estimator=sum)
#       3 plt.title('Total Sales by Product')
#
# NameError: name 'plt' is not defined
